# %% [markdown]
# ### Step 1 - Decide in which city the company should be based
#
# Decision should be based on:
# 1. Number of Design Companies
# 2. Number of

# %% [markdown]
# #### Libraries

# %%
from pymongo import MongoClient
client = MongoClient("localhost:27017")
import pandas as pd
import numpy as np
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import geopandas as gpd
import time
import requests

# %%
db = client.get_database('Ironhack')

# %%
c = db.get_collection('companies_collection')
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Ironhack'), 'companies_collection')

# %% [markdown]
# Designers (23%) and Developers (17%) compose 40% of the workforce.
#
# The company has a higher chance to recruit and retain good talent in those areas if they are located in a place that is either:
# 1. near design companies <br>
# OR
# 2. near successful tech startups that have raised more tham 1M

# %%
# FIND DESIGN COMPANIES:
query_design = {"tag_list" : {'$regex':'.*design.*'}}


#FIND TECH STARTUPS:
tech_1 = {'total_money_raised':{'$regex':'M'}}
tech_2 = {'founded_year': {'$lte': 2015}}
tech_3 = {"category_code" : {'$regex':'tech'}}
query_tech = {'$and': [
    tech_1, tech_2, tech_3
]}
projection = {'_id': 0, 'name': 1, 'total_money_raised' : 1, 'offices.country_code' : 1, 'offices.city' : 1, 'offices.latitude': 1, 'offices.longitude': 1}

query_all = {'$or': [query_design, query_tech]}

companies_filtered = list(c.find(query_all, projection))
len(companies_filtered)
#res
# Out:
# 956

# %%
design_companies = list(c.find(query_design, projection))

# %%
tech_companies = list(c.find(query_tech, projection))

# %%
companies_filtered
# Out:
# [{'name': 'Digg',
#   'total_money_raised': '$45M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.764726,
#     'longitude': -122.394523}]},
#  {'name': 'Adobe Systems',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.320052,
#     'longitude': -121.877636}]},
#  {'name': 'Negonation',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'ESP',
#     'latitude': 40.463667,
#     'longitude': -3.74922}]},
#  {'name': 'GENWI',
#   'total_money_raised': '$7.1M',
#   'offices': [{'city': 'Los Altos',
#     'country_code': 'USA',
#     'latitude': 33.8171,
#     'longitude': -111.9035}]},
#  {'name': 'Aviary',
#   'total_money_raised': '$19M',
#   'offices': [{'city': 'NY',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'BrightQube',
#   'total_money_raised': '$850k',
#   'offices': [{'city': 'Carlsbad',
#     'country_code': 'USA',
#     'latitude': 33.09568,
#     'longitude': -117.244034}]},
#  {'name': 'Ponoko',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Oakland',
#     'country_code': 'USA',
#     'latitude': 37.8136086,
#     'longitude': -122.2966496},
#    {'city': 'Wellington',
#     'country_code': 'NZL',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': '23andMe',
#   'total_money_raised': '$161M',
#   'offices': [{'city': 'Mountain View',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'The Climate Corporation',
#   'total_money_raised': '$109M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.782809,
#     'longitude': -122.394354},
#    {'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.5984767,
#     'longitude': -122.3331466}]},
#  {'name': 'Wix',
#   'total_money_raised': '$58.5M',
#   'offices': [{'city': 'Tel Aviv',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Gilt Groupe',
#   'total_money_raised': '$236M',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.74727,
#     'longitude': -73.9800645}]},
#  {'name': 'GridPoint',
#   'total_money_raised': '$285M',
#   'offices': [{'city': 'Arlington',
#     'country_code': 'USA',
#     'latitude': 38.888107,
#     'longitude': -77.091562}]},
#  {'name': 'HelioVolt',
#   'total_money_raised': '$253M',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.216908,
#     'longitude': -97.685078}]},
#  {'name': 'Kior',
#   'total_money_raised': '$298M',
#   'offices': [{'city': 'Pasadena',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'Nanosolar',
#   'total_money_raised': '$520M',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.264749,
#     'longitude': -121.789862}]},
#  {'name': 'AF83',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'PARIS',
#     'country_code': 'FRA',
#     'latitude': 48.862063,
#     'longitude': 2.35022},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Sitemasher',
#   'total_money_raised': 'C$5M',
#   'offices': [{'city': 'Vancouver',
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Coral Gables',
#     'country_code': 'USA',
#     'latitude': 25.705057,
#     'longitude': -80.271378}]},
#  {'name': 'cScape',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.523676,
#     'longitude': -0.107843}]},
#  {'name': 'EnergyWeb Solutions',
#   'total_money_raised': '$100k',
#   'offices': [{'city': 'Allentown',
#     'country_code': 'USA',
#     'latitude': 40.58471,
#     'longitude': -75.588974},
#    {'city': 'Allentown',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ProofHQ',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.5320478,
#     'longitude': -0.011154}]},
#  {'name': '99designs',
#   'total_money_raised': '$35M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.7955307,
#     'longitude': -122.4005983},
#    {'city': 'Collingwood',
#     'country_code': 'AUS',
#     'latitude': -37.8026587,
#     'longitude': 144.9868546},
#    {'city': 'Berlin',
#     'country_code': 'DEU',
#     'latitude': 52.4986199,
#     'longitude': 13.4469031}]},
#  {'name': 'Digital-Telepathy',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 32.736369,
#     'longitude': -117.160619}]},
#  {'name': 'Feng-GUI',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Tel Aviv',
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595}]},
#  {'name': 'Dotndot',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Hyderabad',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Osidosi Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'CAN',
#     'latitude': 56.130366,
#     'longitude': -106.346771}]},
#  {'name': 'Posit Science',
#   'total_money_raised': '$11.8M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Less Everything',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Jacksonville',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Mojizu',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Irvine',
#     'country_code': 'USA',
#     'latitude': 33.690354,
#     'longitude': -117.829435}]},
#  {'name': 'Carsonified',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bath',
#     'country_code': 'GBR',
#     'latitude': 51.381732,
#     'longitude': -2.365654}]},
#  {'name': 'Akvo',
#   'total_money_raised': '€1.71M',
#   'offices': [{'city': 'Delft',
#     'country_code': 'NLD',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Sososher',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'name': 'Designing Interactive',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Rocky River',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'RiDE Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Newark',
#     'country_code': 'USA',
#     'latitude': 39.677485,
#     'longitude': -75.753563}]},
#  {'name': 'Weardrobe',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.446662,
#     'longitude': -122.164925}]},
#  {'name': 'Brilliant2',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.043228,
#     'longitude': -118.46856}]},
#  {'name': 'EasyLink',
#   'total_money_raised': '$5.4M',
#   'offices': [{'city': 'Chennai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'groSolar',
#   'total_money_raised': '$2.5M',
#   'offices': [{'city': 'White River',
#     'country_code': 'USA',
#     'latitude': 43.662181,
#     'longitude': -72.352081}]},
#  {'name': 'eSolar',
#   'total_money_raised': '$192M',
#   'offices': [{'city': 'Pasadena',
#     'country_code': 'USA',
#     'latitude': 34.146436,
#     'longitude': -118.153136}]},
#  {'name': 'Shopflick',
#   'total_money_raised': '$8M',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.044939,
#     'longitude': -118.419067}]},
#  {'name': 'PixelCrayons',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 28.682042,
#     'longitude': 77.087502}]},
#  {'name': 'Trunkt', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'myTino',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Hangzhou',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Visible Theory',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Pasadena',
#     'country_code': 'USA',
#     'latitude': 34.145904,
#     'longitude': -118.129329}]},
#  {'name': 'Janmedia Interactive',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Falls Church',
#     'country_code': 'USA',
#     'latitude': 38.878596,
#     'longitude': -77.185057}]},
#  {'name': 'Cutcaster',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.79851,
#     'longitude': -122.457454}]},
#  {'name': 'Mad Mimi',
#   'total_money_raised': '$110k',
#   'offices': [{'city': 'Brooklyn',
#     'country_code': 'USA',
#     'latitude': 40.66509,
#     'longitude': -73.980306}]},
#  {'name': 'New York Designs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.743264,
#     'longitude': -73.923427}]},
#  {'name': 'Apperceptive', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Tornado Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Phoenix',
#     'country_code': 'USA',
#     'latitude': 33.479692,
#     'longitude': -111.980855}]},
#  {'name': 'Springleap',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Cape Town',
#     'country_code': 'ZAF',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Inovatis',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Lipsheim',
#     'country_code': 'FRA',
#     'latitude': 48.491885,
#     'longitude': 7.664067}]},
#  {'name': 'Tumblize',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'SEO Workers',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Augsburg',
#     'country_code': 'DEU',
#     'latitude': 48.333702,
#     'longitude': 10.90602}]},
#  {'name': 'Infinia',
#   'total_money_raised': '$152M',
#   'offices': [{'city': 'OGDEN',
#     'country_code': 'USA',
#     'latitude': 46.220919,
#     'longitude': -119.22322}]},
#  {'name': 'JumpFrog',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Hazleton',
#     'country_code': 'USA',
#     'latitude': 40.977855,
#     'longitude': -76.029511}]},
#  {'name': 'deviantART',
#   'total_money_raised': '$13.5M',
#   'offices': [{'city': 'Hollywood',
#     'country_code': 'USA',
#     'latitude': 34.101578,
#     'longitude': -118.33334}]},
#  {'name': 'Crunchlabz',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Rotterdam',
#     'country_code': 'NLD',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'MakeMyLink',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'new delhi',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Global Business Development Services',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Ashland',
#     'country_code': 'USA',
#     'latitude': 42.1827347,
#     'longitude': -122.7032759}]},
#  {'name': 'ExpertsYard',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Dallas',
#     'country_code': 'USA',
#     'latitude': 32.789215,
#     'longitude': -96.788551}]},
#  {'name': 'Sirtris Pharmaceuticals',
#   'total_money_raised': '$82M',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': 42.363567,
#     'longitude': -71.091189}]},
#  {'name': 'Acquity Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.881876,
#     'longitude': -87.639713}]},
#  {'name': 'InterGraphicDESIGNS',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'TibÃ¡s, San JosÃ©',
#     'country_code': 'CRI',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Monkey in your Soul',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Toronto',
#     'country_code': 'CAN',
#     'latitude': 43.670233,
#     'longitude': -79.386755}]},
#  {'name': 'AdapDev IT Web Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Puyallup',
#     'country_code': 'USA',
#     'latitude': 47.156038,
#     'longitude': -122.357183}]},
#  {'name': 'Artifex Animation Studios',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Montreal',
#     'country_code': 'CAN',
#     'latitude': 45.539065,
#     'longitude': -73.609532}]},
#  {'name': 'Fabric Interactive',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.0748,
#     'longitude': -118.288536}]},
#  {'name': 'RMW Web Publishing',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bathurst',
#     'country_code': 'AUS',
#     'latitude': -33.41978,
#     'longitude': 149.574258}]},
#  {'name': 'FliteHaus Creative Agency',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Oviedo',
#     'country_code': 'USA',
#     'latitude': 28.544123,
#     'longitude': -81.366414}]},
#  {'name': 'Majides',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'JPN',
#     'latitude': 36.204824,
#     'longitude': 138.252924}]},
#  {'name': 'ArcStone Technologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Minneapolis',
#     'country_code': 'USA',
#     'latitude': 44.962697,
#     'longitude': -93.279911}]},
#  {'name': 'Mobile Rider',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Salt Lake City',
#     'country_code': 'USA',
#     'latitude': 40.739109,
#     'longitude': -111.887733}]},
#  {'name': 'BrightSource Energy',
#   'total_money_raised': '$845M',
#   'offices': [{'city': 'Oakland',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Bonsource Technology',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chennai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ZPower',
#   'total_money_raised': '$123M',
#   'offices': [{'city': 'Camarillo',
#     'country_code': 'USA',
#     'latitude': 34.197333,
#     'longitude': -119.009054}]},
#  {'name': 'Wilogo',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Saint Chamond',
#     'country_code': 'FRA',
#     'latitude': 45.509034,
#     'longitude': 4.580496}]},
#  {'name': '22Plus Network',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Iasi',
#     'country_code': 'ROM',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Synthetic Entertainment',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Manhattan',
#     'country_code': 'USA',
#     'latitude': 39.1967,
#     'longitude': -96.5956}]},
#  {'name': 'Firefly Energy',
#   'total_money_raised': '$31M',
#   'offices': [{'city': 'Peoria',
#     'country_code': 'USA',
#     'latitude': 40.76652,
#     'longitude': -89.571813}]},
#  {'name': '939 Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'East Yorkshire',
#     'country_code': 'GBR',
#     'latitude': 53.725204,
#     'longitude': -0.439392}]},
#  {'name': 'BootB', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Zulu Creative',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'West Midlands',
#     'country_code': 'GBR',
#     'latitude': 52.588545,
#     'longitude': -1.830892}]},
#  {'name': 'Making Sense',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Antonio',
#     'country_code': 'USA',
#     'latitude': 29.516352,
#     'longitude': -98.43676},
#    {'city': 'Buenos Aires',
#     'country_code': 'ARG',
#     'latitude': -34.5892808,
#     'longitude': -58.43297},
#    {'city': 'Mar del Plata',
#     'country_code': 'ARG',
#     'latitude': -38.0060917,
#     'longitude': -57.5582444}]},
#  {'name': 'Aurora Biofuels',
#   'total_money_raised': '$102M',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 37.6266932,
#     'longitude': -122.1169032},
#    {'city': 'Hayward',
#     'country_code': 'USA',
#     'latitude': 37.6688205,
#     'longitude': -122.0807964}]},
#  {'name': 'MakeFive',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Vancouver, BC',
#     'country_code': 'CAN',
#     'latitude': 49.2839417,
#     'longitude': -123.1101383}]},
#  {'name': 'New Media Strategies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Arlington',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Louis Vuitton',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.871976,
#     'longitude': 2.30069}]},
#  {'name': 'Fashionspace',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Guernsey',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Addesso',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Drexel Hill',
#     'country_code': 'USA',
#     'latitude': 39.947465,
#     'longitude': -75.288083}]},
#  {'name': 'Aurus IT Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Mumbai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Ensign Technologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Springfield',
#     'country_code': 'USA',
#     'latitude': 37.207262,
#     'longitude': -93.302443}]},
#  {'name': 'modula', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Bilende Technologies',
#   'total_money_raised': '$100k',
#   'offices': [{'city': 'Istanbul',
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Rui Peixeiro',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'CovilhÃ£',
#     'country_code': 'PRT',
#     'latitude': 40.29416,
#     'longitude': -7.469215}]},
#  {'name': 'Talent Gurus',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Houston',
#     'country_code': 'USA',
#     'latitude': 30.050837,
#     'longitude': -95.230789}]},
#  {'name': 'Tangivel',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Coimbra',
#     'country_code': 'PRT',
#     'latitude': 40.19266,
#     'longitude': -8.418228},
#    {'city': 'Viseu',
#     'country_code': 'PRT',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Union Street Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Burlington',
#     'country_code': 'USA',
#     'latitude': 44.468055,
#     'longitude': -73.207641}]},
#  {'name': 'Klee Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Le Plessis Robinson',
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'QRIU',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'PRT',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Lehigh Technologies',
#   'total_money_raised': '$55.5M',
#   'offices': [{'city': 'Tucker',
#     'country_code': 'USA',
#     'latitude': 26.215648,
#     'longitude': -81.80187}]},
#  {'name': 'Catalyst Resources',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Mateo',
#     'country_code': 'USA',
#     'latitude': 37.552137,
#     'longitude': -122.314156},
#    {'city': 'Washington',
#     'country_code': 'USA',
#     'latitude': 40.75604,
#     'longitude': -73.986941}]},
#  {'name': 'ShopMyCloset',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': '',
#     'country_code': 'USA',
#     'latitude': 40.75604,
#     'longitude': -73.986941}]},
#  {'name': 'Mashware', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'DesignBay', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'vunite media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Salt Lake City',
#     'country_code': 'USA',
#     'latitude': 40.766429,
#     'longitude': -111.858952}]},
#  {'name': 'MEDDIA',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Barcelona',
#     'country_code': 'ESP',
#     'latitude': 41.4018094,
#     'longitude': 2.1815648}]},
#  {'name': 'Meetweb',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Napoli',
#     'country_code': 'ITA',
#     'latitude': 40.838338,
#     'longitude': 14.235889}]},
#  {'name': 'ecreative',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'istanbul',
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Anubavam',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Antonio',
#     'country_code': 'USA',
#     'latitude': 29.743772,
#     'longitude': -98.692465},
#    {'city': 'Chennai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Dot Com Infoway France',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chennai',
#     'country_code': 'IND',
#     'latitude': 13.11352,
#     'longitude': 80.152135}]},
#  {'name': 'Segway',
#   'total_money_raised': '$161M',
#   'offices': [{'city': 'Bedford',
#     'country_code': 'USA',
#     'latitude': 42.928152,
#     'longitude': -71.45672}]},
#  {'name': 'IDEO',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.441971,
#     'longitude': -122.161151},
#    {'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': 42.363936,
#     'longitude': -71.101238},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.522272,
#     'longitude': -0.109804},
#    {'city': 'Evanston',
#     'country_code': 'USA',
#     'latitude': 42.046475,
#     'longitude': -87.680813},
#    {'city': 'Munich',
#     'country_code': 'DEU',
#     'latitude': 48.136592,
#     'longitude': 11.580102},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.721026,
#     'longitude': -74.001614},
#    {'city': 'Shanghai',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Ammunition Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Padova',
#     'country_code': 'ITA',
#     'latitude': 45.409568,
#     'longitude': 11.876589}]},
#  {'name': 'Spoiltchild',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Drogheda',
#     'country_code': 'IRL',
#     'latitude': 40.19036,
#     'longitude': -74.840241}]},
#  {'name': 'KIPL',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Mumbai (Bombay)',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'SulfurCell',
#   'total_money_raised': '$159M',
#   'offices': [{'city': 'Berlin',
#     'country_code': 'DEU',
#     'latitude': 52.432644,
#     'longitude': 13.522974}]},
#  {'name': 'Fixie',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.6042792,
#     'longitude': -122.3374372}]},
#  {'name': 'Bizcard',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Scottsdale',
#     'country_code': 'USA',
#     'latitude': 33.5093,
#     'longitude': -111.8985}]},
#  {'name': 'Gorenje',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Wien',
#     'country_code': 'AUT',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Sarajevo',
#     'country_code': 'BIH',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Zagreb',
#     'country_code': 'HRV',
#     'latitude': 45.793899,
#     'longitude': 15.961251},
#    {'city': 'Levallois-Perret',
#     'country_code': 'FRA',
#     'latitude': 48.896914,
#     'longitude': 2.288335}]},
#  {'name': 'Adorn Technologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Coimbatore',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ecimtech', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'IPsupermarket',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Continuum',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'West Newton',
#     'country_code': 'USA',
#     'latitude': 42.349239,
#     'longitude': -71.223834},
#    {'city': 'Milano',
#     'country_code': 'ITA',
#     'latitude': 45.447302,
#     'longitude': 9.215569},
#    {'city': 'Seoul',
#     'country_code': 'KOR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Aldor Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Plano',
#     'country_code': 'USA',
#     'latitude': 33.010381,
#     'longitude': -96.705127}]},
#  {'name': 'Biden PC',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Pomona',
#     'country_code': 'USA',
#     'latitude': 34.109193,
#     'longitude': -117.755169}]},
#  {'name': 'Wharton Website Design and Marketing',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Mountain Home',
#     'country_code': 'USA',
#     'latitude': 36.338746,
#     'longitude': -92.363837}]},
#  {'name': 'Reverb Studios',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Carrick-on-Shannon',
#     'country_code': 'IRL',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Leafish',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Wrexham',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Ocean Online Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.886088,
#     'longitude': -87.624983}]},
#  {'name': 'Coomer Media Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Richmond',
#     'country_code': 'USA',
#     'latitude': 37.747342,
#     'longitude': -84.294064}]},
#  {'name': 'White Light Concepts', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'DigitiseUrDreams', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'WebMedic',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Delft',
#     'country_code': 'NLD',
#     'latitude': 52.004819,
#     'longitude': 4.35927}]},
#  {'name': 'Carbonetworks',
#   'total_money_raised': '$5M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.805289,
#     'longitude': -122.404448}]},
#  {'name': 'Minted',
#   'total_money_raised': '$52.7M',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.797435,
#     'longitude': -122.403175}]},
#  {'name': 'Media Lantern',
#   'total_money_raised': '$250k',
#   'offices': [{'city': 'New London',
#     'country_code': 'USA',
#     'latitude': 41.354796,
#     'longitude': -72.097348}]},
#  {'name': 'I-COM',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Manchester',
#     'country_code': 'GBR',
#     'latitude': 53.385028,
#     'longitude': -2.354238}]},
#  {'name': 'Qovax',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Agoura Hills',
#     'country_code': 'USA',
#     'latitude': 34.146149,
#     'longitude': -118.761265}]},
#  {'name': 'StyleCard',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.738137,
#     'longitude': -74.0058}]},
#  {'name': 'GreenRoad Technologies',
#   'total_money_raised': '$58.4M',
#   'offices': [{'city': 'Redwood Shores',
#     'country_code': 'USA',
#     'latitude': 37.527315,
#     'longitude': -122.263434},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Or-Yehuda',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Handcrafted',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Houston',
#     'country_code': 'USA',
#     'latitude': 29.983076,
#     'longitude': -95.5627227}]},
#  {'name': 'Relativity',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'N. Attleboro',
#     'country_code': 'USA',
#     'latitude': 41.957177,
#     'longitude': -71.3607}]},
#  {'name': 'XFRIDAY',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Faridabad',
#     'country_code': 'IND',
#     'latitude': 28.382219,
#     'longitude': 77.303093},
#    {'city': 'Faridabad',
#     'country_code': 'IND',
#     'latitude': 28.382219,
#     'longitude': 77.303093},
#    {'city': '', 'country_code': 'IND', 'latitude': None, 'longitude': None},
#    {'city': 'Mohali',
#     'country_code': 'IND',
#     'latitude': 30.703846,
#     'longitude': 76.718667}]},
#  {'name': 'Mightybytes',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.977257,
#     'longitude': -87.668365}]},
#  {'name': 'EffectiveUI',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Denver',
#     'country_code': 'USA',
#     'latitude': 39.755152,
#     'longitude': -104.990968},
#    {'city': 'Rochester',
#     'country_code': 'USA',
#     'latitude': 43.158821,
#     'longitude': -77.585297}]},
#  {'name': 'Transposagen Biopharmaceuticals',
#   'total_money_raised': '$5.38M',
#   'offices': [{'city': 'Lexington',
#     'country_code': 'USA',
#     'latitude': 38.048906,
#     'longitude': -84.499838}]},
#  {'name': 'LucrativDesigns', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Goldstein Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bensalem',
#     'country_code': 'USA',
#     'latitude': 40.10115,
#     'longitude': -74.941677},
#    {'city': 'Philadelphia',
#     'country_code': 'USA',
#     'latitude': 40.1108242,
#     'longitude': -75.0245215},
#    {'city': 'Maplewood',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'WebMindz24', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Amnesia Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'East Sydney',
#     'country_code': 'AUS',
#     'latitude': -33.876658,
#     'longitude': 151.213362}]},
#  {'name': 'Virtually Canadian',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Vancouver',
#     'country_code': 'CAN',
#     'latitude': 49.277711,
#     'longitude': -123.113775}]},
#  {'name': 'Kinoma',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.43938,
#     'longitude': -122.158804}]},
#  {'name': 'Magic Logix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Carrollton',
#     'country_code': 'USA',
#     'latitude': 32.976452,
#     'longitude': -96.843958}]},
#  {'name': 'The Tin',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.52129,
#     'longitude': -0.10978}]},
#  {'name': 'designgeist', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'CompuBase Internet Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Mill',
#     'country_code': 'NLD',
#     'latitude': 51.67937,
#     'longitude': 5.782043}]},
#  {'name': 'Albion',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Squiz UK',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': 51.521603,
#     'longitude': -0.083444},
#    {'city': 'Edinburgh',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'NuZoo Media', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'e-Man',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London,',
#     'country_code': 'GBR',
#     'latitude': 51.517712,
#     'longitude': -0.141022}]},
#  {'name': 'Dreams Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Mumbai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Design by Humans',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chico',
#     'country_code': 'USA',
#     'latitude': 39.7324184,
#     'longitude': -121.8211856}]},
#  {'name': 'Digital Stampede',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chicago',
#     'country_code': 'USA',
#     'latitude': 41.972002,
#     'longitude': -87.703656}]},
#  {'name': 'D2 Creative',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Somerset',
#     'country_code': 'USA',
#     'latitude': 40.531055,
#     'longitude': -74.519047}]},
#  {'name': 'Face Your Manga', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Pricelock',
#   'total_money_raised': '$12M',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.518539,
#     'longitude': -122.254275}]},
#  {'name': 'AYCE Internet',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Toronto',
#     'country_code': 'CAN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Snaptortoise',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Portland',
#     'country_code': 'USA',
#     'latitude': 45.516621,
#     'longitude': -122.63457}]},
#  {'name': 'Sixty Five Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Beverly Hills',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'HelpMeTy',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'New Brighton',
#     'country_code': 'USA',
#     'latitude': 45.045772,
#     'longitude': -93.190885}]},
#  {'name': 'Ecolect',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.776769,
#     'longitude': -122.410111},
#    {'city': 'Providence',
#     'country_code': 'USA',
#     'latitude': 41.817973,
#     'longitude': -71.441418}]},
#  {'name': 'Insyde',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Delft',
#     'country_code': 'NLD',
#     'latitude': 52.0112727,
#     'longitude': 4.3532861}]},
#  {'name': 'tish-o',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Istanbul',
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'FashionFreax GmbH',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'WÃ¤chtersbach',
#     'country_code': 'DEU',
#     'latitude': 52.537588,
#     'longitude': 13.37402}]},
#  {'name': 'Arcadia Biosciences',
#   'total_money_raised': '$1.99M',
#   'offices': [{'city': 'Davis',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Deeya Energy',
#   'total_money_raised': '$15M',
#   'offices': [{'city': 'Fremont',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Petra Solar',
#   'total_money_raised': '$40M',
#   'offices': [{'city': 'South Plainfield',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Pond5',
#   'total_money_raised': '$500k',
#   'offices': [{'city': 'Brooklyn',
#     'country_code': 'USA',
#     'latitude': 40.7032884,
#     'longitude': -73.9878525},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7280992,
#     'longitude': -73.9933841}]},
#  {'name': 'CoffeeCup Software',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Atlanta',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Hyva IT Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Interworld Commnet', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Synergie Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Agadir',
#     'country_code': 'MAR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Rotterdam',
#     'country_code': 'NLD',
#     'latitude': 51.960189,
#     'longitude': 4.474856}]},
#  {'name': 'dimension5 labs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Santa Fe',
#     'country_code': 'USA',
#     'latitude': 35.6746751,
#     'longitude': -105.9484344}]},
#  {'name': 'Mobclix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.448598,
#     'longitude': -122.158497}]},
#  {'name': 'Popego',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Buenos Aires',
#     'country_code': 'ARG',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.778687,
#     'longitude': -122.421242}]},
#  {'name': 'IncSpring',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Antonio',
#     'country_code': 'USA',
#     'latitude': 29.520005,
#     'longitude': -98.488402}]},
#  {'name': 'SG2',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Capital Federal',
#     'country_code': 'ARG',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Blank Canvas Studios', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'GreenLogic India Tecnologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': 12.9093426,
#     'longitude': 77.5833979}]},
#  {'name': 'Wonsys',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Milan',
#     'country_code': 'ITA',
#     'latitude': 45.468399,
#     'longitude': 9.214761},
#    {'city': 'Bergamo',
#     'country_code': 'ITA',
#     'latitude': 45.692026,
#     'longitude': 9.663717}]},
#  {'name': 'Milobox',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.792979,
#     'longitude': -122.421242}]},
#  {'name': 'Davai Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Montreal',
#     'country_code': 'CAN',
#     'latitude': 45.496141,
#     'longitude': -73.63222}]},
#  {'name': 'Intelligenes',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Karachi',
#     'country_code': 'PAK',
#     'latitude': 24.9068278,
#     'longitude': 67.0806218}]},
#  {'name': 'SnapPages',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.443493,
#     'longitude': -97.77512}]},
#  {'name': 'Raizlabs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Cinergix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Melbourne',
#     'country_code': 'AUS',
#     'latitude': -37.793125,
#     'longitude': 144.971266}]},
#  {'name': 'GolterGraphix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Rochester',
#     'country_code': 'USA',
#     'latitude': 43.3104064,
#     'longitude': -70.9903438}]},
#  {'name': 'Fresh Web Services',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Leicester',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Nealite',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Fran',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Spiral Shell Web LLC',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'East Hampton',
#     'country_code': 'USA',
#     'latitude': 41.595196,
#     'longitude': -72.51949}]},
#  {'name': 'DESIGN about TOWN',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'SF',
#     'country_code': 'USA',
#     'latitude': 37.797909,
#     'longitude': -122.403312}]},
#  {'name': 'HelpMeTy',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'New Brighton',
#     'country_code': 'USA',
#     'latitude': 45.045772,
#     'longitude': -93.190885}]},
#  {'name': 'Ecolect',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.776769,
#     'longitude': -122.410111},
#    {'city': 'Providence',
#     'country_code': 'USA',
#     'latitude': 41.817973,
#     'longitude': -71.441418}]},
#  {'name': 'Insyde',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Delft',
#     'country_code': 'NLD',
#     'latitude': 52.0112727,
#     'longitude': 4.3532861}]},
#  {'name': 'tish-o',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Istanbul',
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'FashionFreax GmbH',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'WÃ¤chtersbach',
#     'country_code': 'DEU',
#     'latitude': 52.537588,
#     'longitude': 13.37402}]},
#  {'name': 'Arcadia Biosciences',
#   'total_money_raised': '$1.99M',
#   'offices': [{'city': 'Davis',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Deeya Energy',
#   'total_money_raised': '$15M',
#   'offices': [{'city': 'Fremont',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Petra Solar',
#   'total_money_raised': '$40M',
#   'offices': [{'city': 'South Plainfield',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Pond5',
#   'total_money_raised': '$500k',
#   'offices': [{'city': 'Brooklyn',
#     'country_code': 'USA',
#     'latitude': 40.7032884,
#     'longitude': -73.9878525},
#    {'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.7280992,
#     'longitude': -73.9933841}]},
#  {'name': 'CoffeeCup Software',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Atlanta',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Hyva IT Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Interworld Commnet', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Synergie Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Agadir',
#     'country_code': 'MAR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Rotterdam',
#     'country_code': 'NLD',
#     'latitude': 51.960189,
#     'longitude': 4.474856}]},
#  {'name': 'dimension5 labs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Santa Fe',
#     'country_code': 'USA',
#     'latitude': 35.6746751,
#     'longitude': -105.9484344}]},
#  {'name': 'Mobclix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.448598,
#     'longitude': -122.158497}]},
#  {'name': 'Popego',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Buenos Aires',
#     'country_code': 'ARG',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.778687,
#     'longitude': -122.421242}]},
#  {'name': 'IncSpring',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Antonio',
#     'country_code': 'USA',
#     'latitude': 29.520005,
#     'longitude': -98.488402}]},
#  {'name': 'SG2',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Capital Federal',
#     'country_code': 'ARG',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Blank Canvas Studios', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'GreenLogic India Tecnologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangalore',
#     'country_code': 'IND',
#     'latitude': 12.9093426,
#     'longitude': 77.5833979}]},
#  {'name': 'Wonsys',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Milan',
#     'country_code': 'ITA',
#     'latitude': 45.468399,
#     'longitude': 9.214761},
#    {'city': 'Bergamo',
#     'country_code': 'ITA',
#     'latitude': 45.692026,
#     'longitude': 9.663717}]},
#  {'name': 'Milobox',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.792979,
#     'longitude': -122.421242}]},
#  {'name': 'Davai Design',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Montreal',
#     'country_code': 'CAN',
#     'latitude': 45.496141,
#     'longitude': -73.63222}]},
#  {'name': 'Intelligenes',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Karachi',
#     'country_code': 'PAK',
#     'latitude': 24.9068278,
#     'longitude': 67.0806218}]},
#  {'name': 'SnapPages',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.443493,
#     'longitude': -97.77512}]},
#  {'name': 'Raizlabs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Cinergix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Melbourne',
#     'country_code': 'AUS',
#     'latitude': -37.793125,
#     'longitude': 144.971266}]},
#  {'name': 'GolterGraphix',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Rochester',
#     'country_code': 'USA',
#     'latitude': 43.3104064,
#     'longitude': -70.9903438}]},
#  {'name': 'Fresh Web Services',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Leicester',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Nealite',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'San Fran',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Spiral Shell Web LLC',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'East Hampton',
#     'country_code': 'USA',
#     'latitude': 41.595196,
#     'longitude': -72.51949}]},
#  {'name': 'DESIGN about TOWN',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'SF',
#     'country_code': 'USA',
#     'latitude': 37.797909,
#     'longitude': -122.403312}]},
#  {'name': 'Zen Web Solutions',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Rochdale',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Lounge|Press',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Boynton Beach',
#     'country_code': 'USA',
#     'latitude': 26.539706,
#     'longitude': -80.108189}]},
#  {'name': 'Drage Web Solutions', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Webguru-India',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Kolkata',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'CPC Computer Consultants',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Miami',
#     'country_code': 'USA',
#     'latitude': 25.761296,
#     'longitude': -80.191258}]},
#  {'name': 'Alwayswater',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Hoboken',
#     'country_code': 'USA',
#     'latitude': 40.747005,
#     'longitude': -74.039011}]},
#  {'name': 'My Modern Metropolis',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'McIntyre Media',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Cleveland',
#     'country_code': 'USA',
#     'latitude': 41.390918,
#     'longitude': -81.554755}]},
#  {'name': 'Glued Network',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'St. Louis',
#     'country_code': 'USA',
#     'latitude': 38.627522,
#     'longitude': -90.19841}]},
#  {'name': 'Devnet',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'BRISBANE',
#     'country_code': 'AUS',
#     'latitude': -27.458989,
#     'longitude': 153.043228}]},
#  {'name': 'Infinity Pharmaceuticals',
#   'total_money_raised': '$156M',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Develop Daly', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'hornet',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Balmain',
#     'country_code': 'AUS',
#     'latitude': -33.86322,
#     'longitude': 151.179693}]},
#  {'name': 'Webtrade',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Dublin',
#     'country_code': 'IRL',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'nodes',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Norman',
#     'country_code': 'USA',
#     'latitude': 35.218428,
#     'longitude': -97.464788}]},
#  {'name': 'Lumenergi',
#   'total_money_raised': '$26.4M',
#   'offices': [{'city': 'Newark',
#     'country_code': 'USA',
#     'latitude': 37.51821,
#     'longitude': -122.044025}]},
#  {'name': 'NOTCOT',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'psd2css Online',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Encinitas',
#     'country_code': 'USA',
#     'latitude': 33.052083,
#     'longitude': -117.279368}]},
#  {'name': 'eDLink Services Pte Ltd',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Singapore',
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Johor Bahru',
#     'country_code': 'MYS',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Designious', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Vinfotech',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Indore',
#     'country_code': 'IND',
#     'latitude': 22.72939,
#     'longitude': 75.883168}]},
#  {'name': 'The Factory Interactive',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Miami',
#     'country_code': 'USA',
#     'latitude': 25.825503,
# ...
#  {'name': 'Brainsgate',
#   'total_money_raised': '$37.5M',
#   'offices': [{'city': '',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'DoNanza',
#   'total_money_raised': '$1M',
#   'offices': [{'city': 'Tel Aviv',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Santhos', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Catalyst Biosciences',
#   'total_money_raised': '$95.9M',
#   'offices': [{'city': 'South San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.645401,
#     'longitude': -122.394464}]},
#  {'name': 'Accera',
#   'total_money_raised': '$139M',
#   'offices': [{'city': 'Broomfield',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'PhotoThera',
#   'total_money_raised': '$80.5M',
#   'offices': [{'city': 'Carlsbad',
#     'country_code': 'USA',
#     'latitude': 33.13324,
#     'longitude': -117.275027}]},
#  {'name': 'Parasol Therapeutics',
#   'total_money_raised': '$6.45M',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'ESBATech',
#   'total_money_raised': '$63M',
#   'offices': [{'city': '',
#     'country_code': 'CHE',
#     'latitude': 47.3993302,
#     'longitude': 8.4582269}]},
#  {'name': 'web design companies', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'EGEN',
#   'total_money_raised': '$23.4M',
#   'offices': [{'city': 'Huntsville',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'iBizLog',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Las Vegas',
#     'country_code': 'USA',
#     'latitude': 36.0122687,
#     'longitude': -115.4977708}]},
#  {'name': 'M4K1', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'CoAxia', 'total_money_raised': '$21.5M', 'offices': []},
#  {'name': 'Visiogen',
#   'total_money_raised': '$40M',
#   'offices': [{'city': 'Irvine',
#     'country_code': 'USA',
#     'latitude': 33.646018,
#     'longitude': -117.711994}]},
#  {'name': 'Personal',
#   'total_money_raised': '$21.1M',
#   'offices': [{'city': 'Washington',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Palyon Medical',
#   'total_money_raised': '$21M',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.756054,
#     'longitude': -73.986951},
#    {'city': '', 'country_code': 'USA', 'latitude': None, 'longitude': None}]},
#  {'name': 'Lycera',
#   'total_money_raised': '$41M',
#   'offices': [{'city': 'Ann Arbor',
#     'country_code': 'USA',
#     'latitude': 42.277416,
#     'longitude': -83.733276}]},
#  {'name': 'iScience Interventional',
#   'total_money_raised': '$35.2M',
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.4805104,
#     'longitude': -122.1807356}]},
#  {'name': 'Marinus Pharmaceuticals',
#   'total_money_raised': '$52.4M',
#   'offices': [{'city': 'Branford',
#     'country_code': 'USA',
#     'latitude': 41.29606,
#     'longitude': -72.770691}]},
#  {'name': 'Waveative',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Houston',
#     'country_code': 'USA',
#     'latitude': 29.7726138,
#     'longitude': -95.514493}]},
#  {'name': 'Intradigm Corporation',
#   'total_money_raised': '$37.4M',
#   'offices': [{'city': 'Palo Alto',
#     'country_code': 'USA',
#     'latitude': 37.435768,
#     'longitude': -122.110835}]},
#  {'name': 'Alnara Pharmaceuticals',
#   'total_money_raised': '$55M',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'USA',
#     'latitude': 42.3624253,
#     'longitude': -71.116031}]},
#  {'name': 'PromoteWare',
#   'total_money_raised': '$0',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Rockstar Memoirs',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'North Sydney',
#     'country_code': 'AUS',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Zymeworks',
#   'total_money_raised': '$23.9M',
#   'offices': [{'city': 'Vancouver,BC',
#     'country_code': 'CAN',
#     'latitude': 49.2644563,
#     'longitude': -123.1356715}]},
#  {'name': 'Athenix',
#   'total_money_raised': '$43.5M',
#   'offices': [{'city': 'Research Triangle Park',
#     'country_code': 'USA',
#     'latitude': 35.8893657,
#     'longitude': -78.880602}]},
#  {'name': 'Nuventix',
#   'total_money_raised': '$33.1M',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': 30.239229,
#     'longitude': -97.834211}]},
#  {'name': 'Pearl Therapeutics',
#   'total_money_raised': '$232M',
#   'offices': [{'city': 'Redwood City',
#     'country_code': 'USA',
#     'latitude': 37.502169,
#     'longitude': -122.217727}]},
#  {'name': 'Cyber-Rain',
#   'total_money_raised': '$3.3M',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 34.186206,
#     'longitude': -118.50391}]},
#  {'name': 'Aspen Aerogels',
#   'total_money_raised': '$136M',
#   'offices': [{'city': 'Northborough',
#     'country_code': 'USA',
#     'latitude': 42.347872,
#     'longitude': -71.63034}]},
#  {'name': 'TARIS Biomedical',
#   'total_money_raised': '$46.8M',
#   'offices': [{'city': 'Lexington',
#     'country_code': 'USA',
#     'latitude': 42.4236783,
#     'longitude': -71.2459523}]},
#  {'name': 'XDx',
#   'total_money_raised': '$126M',
#   'offices': [{'city': 'Brisbane',
#     'country_code': 'USA',
#     'latitude': 37.691226,
#     'longitude': -122.4040269}]},
#  {'name': 'Delphi',
#   'total_money_raised': '$8M',
#   'offices': [{'city': '',
#     'country_code': 'USA',
#     'latitude': 42.603532,
#     'longitude': -83.16134}]},
#  {'name': 'EcoSMART Technologies',
#   'total_money_raised': '$9M',
#   'offices': [{'city': 'Alpharetta',
#     'country_code': 'USA',
#     'latitude': 34.0374308,
#     'longitude': -84.2952754}]},
#  {'name': 'CoMentis',
#   'total_money_raised': '$32M',
#   'offices': [{'city': 'South San Francisco',
#     'country_code': 'USA',
#     'latitude': 37.646457,
#     'longitude': -122.394008}]},
#  {'name': 'JinkoSolar Holding',
#   'total_money_raised': '$35M',
#   'offices': [{'city': 'Jiangxi Province',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Shanghai',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Chicago Designz', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'Omikrosys', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'ERTH Technologies',
#   'total_money_raised': '$2M',
#   'offices': [{'city': 'Longmont',
#     'country_code': 'USA',
#     'latitude': 40.093828,
#     'longitude': -105.187208}]},
#  {'name': 'TOMI Environmental Solutions',
#   'total_money_raised': '$4.38M',
#   'offices': [{'city': 'Beverly Hills',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Principle Power',
#   'total_money_raised': '$2.3M',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.5992095,
#     'longitude': -122.3343564}]},
#  {'name': 'NPS',
#   'total_money_raised': '$9.7M',
#   'offices': [{'city': 'Tewkesbury',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Woodland Biofuels',
#   'total_money_raised': 'C$1.25M',
#   'offices': [{'city': 'Ontario',
#     'country_code': 'CAN',
#     'latitude': 43.6455935,
#     'longitude': -79.6944325}]},
#  {'name': 'Clean Mobile',
#   'total_money_raised': '€3.3M',
#   'offices': [{'city': '',
#     'country_code': 'DEU',
#     'latitude': 48.0554409,
#     'longitude': 11.6075086}]},
#  {'name': 'Inspire Medical Systems',
#   'total_money_raised': '$17M',
#   'offices': [{'city': 'Maple Grove',
#     'country_code': 'USA',
#     'latitude': 45.069344,
#     'longitude': -93.4034162}]},
#  {'name': 'Bioscale',
#   'total_money_raised': '$74.6M',
#   'offices': [{'city': 'LEXINGTON',
#     'country_code': 'USA',
#     'latitude': 42.3609606,
#     'longitude': -71.1017618}]},
#  {'name': 'Gotham',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Sydney',
#     'country_code': 'AUS',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Hurrah', 'total_money_raised': '$0', 'offices': []},
#  {'name': 'VytronUS',
#   'total_money_raised': '$34.8M',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.394258,
#     'longitude': -122.032776}]},
#  {'name': 'Mobile Interactive Group',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Orient Green Power',
#   'total_money_raised': '$55M',
#   'offices': [{'city': 'Chennai',
#     'country_code': 'SGP',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'SoloPower',
#   'total_money_raised': '$458M',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.253463,
#     'longitude': -121.782906}]},
#  {'name': 'Neosens',
#   'total_money_raised': '$5.32M',
#   'offices': [{'city': 'LabÃ¨ge Cedex',
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Coskata',
#   'total_money_raised': '$86.2M',
#   'offices': [{'city': 'Warrenville',
#     'country_code': 'USA',
#     'latitude': 41.8035954,
#     'longitude': -88.159371}]},
#  {'name': 'Metallkraft AS',
#   'total_money_raised': '$32.5M',
#   'offices': [{'city': 'Kristiansand',
#     'country_code': 'NOR',
#     'latitude': 58.155769,
#     'longitude': 7.9543206}]},
#  {'name': 'Solairedirect',
#   'total_money_raised': '$26.6M',
#   'offices': [{'city': 'Paris',
#     'country_code': 'FRA',
#     'latitude': 48.8745951,
#     'longitude': 2.3210737}]},
#  {'name': 'Qteros',
#   'total_money_raised': '$47M',
#   'offices': [{'city': 'Marlborough',
#     'country_code': 'USA',
#     'latitude': 42.3253727,
#     'longitude': -71.5854884}]},
#  {'name': 'Trony Solar',
#   'total_money_raised': '$20M',
#   'offices': [{'city': 'Shenzhen',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'SpringSoft',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'San Jose',
#     'country_code': 'USA',
#     'latitude': 37.37027,
#     'longitude': -121.924053}]},
#  {'name': 'The Graphic Design School',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'LOS ANGELES',
#     'country_code': 'USA',
#     'latitude': 34.0878254,
#     'longitude': -118.3794929}]},
#  {'name': 'New Toy',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'London',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'GreenVolts',
#   'total_money_raised': '$96.8M',
#   'offices': [{'city': 'Fremont',
#     'country_code': 'USA',
#     'latitude': 37.790153,
#     'longitude': -122.398669}]},
#  {'name': 'AltaRock Energy',
#   'total_money_raised': '$26.3M',
#   'offices': [{'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.6859295,
#     'longitude': -122.3373282},
#    {'city': 'Seattle',
#     'country_code': 'USA',
#     'latitude': 47.620973,
#     'longitude': -122.347276}]},
#  {'name': 'Semprius',
#   'total_money_raised': '$57.7M',
#   'offices': [{'city': 'Durham',
#     'country_code': 'USA',
#     'latitude': 35.8948471,
#     'longitude': -78.8923523}]},
#  {'name': 'MBA Polymers',
#   'total_money_raised': '$86.2M',
#   'offices': [{'city': 'Richmond',
#     'country_code': 'USA',
#     'latitude': 37.93039,
#     'longitude': -122.374927}]},
#  {'name': 'MentorMate',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Minneapolis',
#     'country_code': 'USA',
#     'latitude': 44.948786,
#     'longitude': -93.161038}]},
#  {'name': 'DuPont', 'total_money_raised': '$9M', 'offices': []},
#  {'name': 'Cogzidel Technologies',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Chennai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Madurai',
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Savara Pharmaceuticals',
#   'total_money_raised': '$30.2M',
#   'offices': [{'city': 'Austin',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Energy and Power Solutions',
#   'total_money_raised': '$30M',
#   'offices': [{'city': 'Trabuco Canyon',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'CPower',
#   'total_money_raised': '$27.7M',
#   'offices': [{'city': 'New York',
#     'country_code': 'USA',
#     'latitude': 40.756054,
#     'longitude': -73.986951}]},
#  {'name': 'Enecsys',
#   'total_money_raised': '$55.1M',
#   'offices': [{'city': 'Cambridge',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Nordic Windpower',
#   'total_money_raised': '$54M',
#   'offices': [{'city': 'Berkeley',
#     'country_code': 'USA',
#     'latitude': 37.863464,
#     'longitude': -122.3153453}]},
#  {'name': 'Collective Core',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Smyrna',
#     'country_code': 'USA',
#     'latitude': 33.8837,
#     'longitude': -84.5144}]},
#  {'name': 'Design Chemical',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Bangkok',
#     'country_code': 'THA',
#     'latitude': 13.764605,
#     'longitude': 100.5642201}]},
#  {'name': 'Techpool Bio-Pharma',
#   'total_money_raised': '$20.5M',
#   'offices': [{'city': '',
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Axis Three',
#   'total_money_raised': '$4.97M',
#   'offices': [{'city': 'Boston',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Crocus Technology',
#   'total_money_raised': '€59M',
#   'offices': [{'city': 'Sunnyvale',
#     'country_code': 'USA',
#     'latitude': 37.386774,
#     'longitude': -121.987661},
#    {'city': 'Grenoble Cedex',
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Catalyst Advertising',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Columbia',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'NanoBio',
#   'total_money_raised': '$39M',
#   'offices': [{'city': 'Ann Arbor',
#     'country_code': 'USA',
#     'latitude': 42.3079711,
#     'longitude': -83.6927623}]},
#  {'name': 'Top Rated Website Designers',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Carlsbad',
#     'country_code': 'USA',
#     'latitude': 33.1412124,
#     'longitude': -117.3205123},
#    {'city': 'Los Angeles',
#     'country_code': 'USA',
#     'latitude': 33.9933257,
#     'longitude': -118.3987842},
#    {'city': 'San Diego',
#     'country_code': 'USA',
#     'latitude': 33.1412124,
#     'longitude': -117.3205123}]},
#  {'name': 'United On-Line',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Galatsi, Attiki',
#     'country_code': 'GRC',
#     'latitude': 38.0088251,
#     'longitude': 23.759331}]},
#  {'name': 'OptiMedica',
#   'total_money_raised': '$51M',
#   'offices': [{'city': 'Santa Clara',
#     'country_code': 'USA',
#     'latitude': 37.3777985,
#     'longitude': -121.9744545}]},
#  {'name': 'Aqwise',
#   'total_money_raised': '$8.1M',
#   'offices': [{'city': '',
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Herzliya',
#     'country_code': 'ISR',
#     'latitude': 32.162413,
#     'longitude': 34.844675}]},
#  {'name': 'Advanced Power Projects',
#   'total_money_raised': '$13M',
#   'offices': [{'city': 'Fremont',
#     'country_code': 'USA',
#     'latitude': 37.5252461,
#     'longitude': -121.9178417}]},
#  {'name': 'ITERNOVA',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Teruel',
#     'country_code': 'ESP',
#     'latitude': 40.3401332,
#     'longitude': -1.1059614},
#    {'city': 'Zaragoza',
#     'country_code': 'ESP',
#     'latitude': 41.6698776,
#     'longitude': -0.8944867}]},
#  {'name': 'Atlantic BT',
#   'total_money_raised': '$0',
#   'offices': [{'city': 'Raleigh',
#     'country_code': 'USA',
#     'latitude': 35.8969064,
#     'longitude': -78.6806784}]},
#  {'name': 'Treehouse',
#   'total_money_raised': '$19.4M',
#   'offices': [{'city': 'Orlando',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Portland',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'name': 'Purfresh',
#   'total_money_raised': '$62.7M',
#   'offices': [{'city': 'Menlo Park',
#     'country_code': 'USA',
#     'latitude': 37.477008,
#     'longitude': -122.151599}]}]

# %%
lat = companies_filtered[0]['offices'][0]['latitude']
lon = companies_filtered[0]['offices'][0]['longitude']
country = companies_filtered[0]['offices'][0]['country_code']

lat, lon, country
# Out:
# (37.764726, -122.394523, 'USA')

# %%
def create_df(companies_filtered):
    data = {'company': [i['name'] for i in companies_filtered],
            'city': [i['offices'][0].get('city', np.nan) if i.get('offices') else np.nan for i in companies_filtered],
            'latitude': [i['offices'][0].get('latitude', np.nan) if i.get('offices') else np.nan for i in companies_filtered],
            'longitude': [i['offices'][0].get('longitude', np.nan) if i.get('offices') else np.nan for i in companies_filtered]
           }
    return pd.DataFrame.from_dict(data, orient='columns')

# %%
df_all = create_df(companies_filtered)

# %%
df_all
# Out:
#                      company           city   latitude   longitude
# 0                       Digg  San Francisco  37.764726 -122.394523
# 1              Adobe Systems       San Jose  37.320052 -121.877636
# 2                 Negonation                 40.463667   -3.749220
# 3                      GENWI      Los Altos  33.817100 -111.903500
# 4                     Aviary             NY        NaN         NaN
# ..                       ...            ...        ...         ...
# 951  Advanced Power Projects        Fremont  37.525246 -121.917842
# 952                 ITERNOVA         Teruel  40.340133   -1.105961
# 953              Atlantic BT        Raleigh  35.896906  -78.680678
# 954                Treehouse        Orlando        NaN         NaN
# 955                 Purfresh     Menlo Park  37.477008 -122.151599
#
# [956 rows x 4 columns]

# %%
df_all.isna().sum()
# Out:
# company        0
# city         105
# latitude     350
# longitude    350
# dtype: int64

# %%
df_all.nunique()
# Out:
# company      924
# city         459
# latitude     580
# longitude    580
# dtype: int64

# %%
df_all.dropna(subset=['latitude', 'longitude'], how='any', inplace=True)

# %%
df_all.nunique()
# Out:
# company      588
# city         353
# latitude     580
# longitude    580
# dtype: int64

# %%
# Create DESIGN companies df and drop Nan lat and long
df_design = create_df(design_companies)
df_design.dropna(subset=['latitude', 'longitude'], how='any', inplace=True)
df_design.sample()
# Out:
#     company    city   latitude  longitude
# 235  Box UK  London  51.510774  -0.139245

# %%
# Create TECH companies df and drop Nan lat and long
df_tech = create_df(tech_companies)
df_tech.dropna(subset=['latitude', 'longitude'], how='any', inplace=True)
df_tech.sample()
# Out:
#                   company city   latitude  longitude
# 172  Aileron Therapeutics       42.101977 -72.637994

# %%
# SEEING DESIGN AND TECH COMPANIES ON A MAP
tech_select = folium.FeatureGroup(name=f"Tech ({df_tech.shape[0]})")
design_select = folium.FeatureGroup(name = f"Design ({df_design.shape[0]})")
HeatMap(data = df_tech[["latitude", "longitude"]]).add_to(tech_select)
HeatMap(data = df_design[["latitude", "longitude"]]).add_to(design_select)
tech_select.add_to(world_map)
design_select.add_to(world_map)
folium.LayerControl(collapsed=False, position="topleft").add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c2ff0a48b7dd6c766526ed21e935c23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c2ff0a48b7dd6c766526ed21e935c23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c2ff0a48b7dd6c766526ed21e935c23 = L.map(
#                 &quot;map_3c2ff0a48b7dd6c766526ed21e935c23&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f37d51314fcf598f2aaa8a8fef75642 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c2ff0a48b7dd6c766526ed21e935c23);
#
#
#             var feature_group_d5f8303ddd6d4859829683f01a6562db = L.featureGroup(
#                 {}
#             ).addTo(map_3c2ff0a48b7dd6c766526ed21e935c23);
#
#
#             var heat_map_d1a66eb95723c62defb856a1c0dd3188 = L.heatLayer(
#                 [[37.09024, -95.712891], [37.782809, -122.394354], [38.888107, -77.091562], [30.216908, -97.685078], [37.09024, -95.712891], [37.264749, -121.789862], [43.662181, -72.352081], [34.146436, -118.153136], [46.220919, -119.22322], [42.363567, -71.091189], [34.197333, -119.009054], [40.76652, -89.571813], [37.6266932, -122.1169032], [26.215648, -81.80187], [42.928152, -71.45672], [52.432644, 13.522974], [37.805289, -122.404448], [37.527315, -122.263434], [38.048906, -84.499838], [37.518539, -122.254275], [37.51821, -122.044025], [37.279485, -121.94356], [37.3987372, -122.0497918], [37.563039, -122.277639], [37.628328, -122.420814], [42.500324, -71.130792], [48.8545738, 2.3216223], [42.3663257, -71.0917952], [37.3949615, -122.1425097], [40.718033, -111.81104], [39.1878563, -77.2610228], [37.5024749, -122.220408], [23.066066, -82.2927796], [51.671711, -1.289082], [39.2328783, -76.8204666], [32.89929, -117.1948], [33.954713, -84.2213281], [37.8715926, -122.272747], [40.02375, -105.226353], [37.5071591, -122.2605222], [37.4757796, -121.9382415], [37.661523, -122.398667], [38.6093764, -90.1959689], [37.6664003, -122.451448], [55.783256, 12.515066], [41.305179, -72.93117], [37.4298665, -122.108852], [37.674378, -122.387699], [41.8819098, -87.6367792], [41.6750038, -88.0642145], [40.7310476, -74.0078134], [39.862942, -105.206509], [37.560781, -122.284114], [26.2032036, -80.1510951], [42.3678629, -71.1998364], [37.2612396, -121.9594672], [37.380364, -121.9823779], [32.88791, -117.176096], [-33.947414, 150.967905], [37.390233, -122.033741], [42.4236783, -71.2459523], [37.7676285, -122.393799], [42.2927344, -85.5796432], [38.992699, -76.93873], [37.6974864, -121.8138788], [60.2268115, 25.014409], [38.9945752, -77.0307225], [34.144014, -118.001268], [39.0610803, -76.8863954], [37.692934, -121.904945], [37.7871306, -122.4041075], [51.4698433, -0.2611303], [34.143507, -118.763605], [37.5511524, -122.060501], [32.749238, -96.840091], [30.161661, -95.471256], [47.6858186, -117.1920026], [42.3853985, -83.5069834], [42.36867, -71.150248], [41.424425, -81.822531], [37.4503251, -122.1164954], [40.7775647, -73.9459335], [40.054099, -76.289191], [42.0231313, -93.57495], [42.5102913, -71.1474063], [37.7871306, -122.4041075], [37.482654, -122.172713], [39.110655, -77.154466], [36.0686005, -115.162279], [29.768442, -95.401093], [33.982967, -84.346041], [40.068752, -105.208027], [32.89892, -117.242961], [46.1685443, 6.1036257], [40.4960244, -111.4199963], [43.3368952, 11.3075198], [59.4995085, 17.9263734], [34.062588, -84.16923], [33.84819, -84.193858], [51.4983521, 6.8126313], [33.0382884, -96.8300836], [37.723803, -122.240937], [37.658713, -122.399382], [37.6656476, -122.3843489], [37.6534817, -122.3956474], [52.1680188, 4.4658637], [40.329677, -74.495653], [42.061187, -88.0794478], [42.830989, -71.489876], [42.392628, -71.151216], [30.327779, -97.669955], [42.101977, -72.637994], [46.5567716, 6.6833176], [53.3401356, -6.2962414], [47.795302, -122.205813], [40.3321605, -74.5014238], [47.6234781, -122.3343544], [37.661543, -122.390464], [32.3462, 34.8615], [29.7847641, -82.4768036], [39.5688576, -105.1236849], [28.7164018, 77.1765029], [40.5932386, -105.0766501], [39.1880124, -119.7480697], [33.7726102, -84.3507414], [37.523194, -122.259179], [35.911347, -78.976038], [41.4225841, -81.3857728], [40.026, -105.259041], [47.598657, -122.334614], [42.3913892, -71.2709869], [37.523311, -122.259154], [42.362856, -71.083762], [46.2038099, 6.1399589], [42.362035, -71.113289], [29.6982817, -95.3500171], [37.9471709, -122.5071031], [40.100058, -75.413354], [37.5062006, -122.2506373], [37.3825306, -121.9198306], [47.6042663, -122.3328401], [52.3965603, 4.85169

# %% [markdown]
# ### USA and UK seem to be hubs for tech and design companies. Let's investigate

# %%
def top_cities(df, column, n=4, columns_to_keep=['city', 'company', 'latitude', 'longitude']):
    """
    Filters a dataframe to contain only the top n most frequent values in a specified column
    Args:
        df (pandas.DataFrame): the dataframe to be filtered
        column (str): the name of the column to count and filter
        n (int): the number of top values to keep (default is 3)
        columns_to_keep (list): the list of columns to keep in the filtered dataframe (default is ['city', 'country', 'name', 'latitude', 'longitude'])
    Returns:
        The filtered dataframe
    """
    value_counts = df[column].value_counts()
    top_values = value_counts[:n].index.tolist()
    return df[df[column].isin(top_values)][columns_to_keep]

# %%
top_cities = top_cities(df, 'city')
top_cities
# Out:
#               city                  company   latitude   longitude
# 0    San Francisco                     Digg  37.764726 -122.394523
# 2                                Negonation  40.463667   -3.749220
# 8    San Francisco  The Climate Corporation  37.782809 -122.394354
# 10        New York              Gilt Groupe  40.747270  -73.980064
# 17          London                   cScape  51.523676   -0.107843
# ..             ...                      ...        ...         ...
# 882       New York           Palyon Medical  40.756054  -73.986951
# 895                              Cyber-Rain  34.186206 -118.503910
# 899                                  Delphi  42.603532  -83.161340
# 910                            Clean Mobile  48.055441   11.607509
# 937       New York                   CPower  40.756054  -73.986951
#
# [61 rows x 4 columns]

# %% [markdown]
# ### Looks like some empty cells in city were not dropped in cleaning 👀

# %%
# Checking the value and value type for row 0 and column 'city' to understand issue
index = 2
column = 'city'
value = df.iloc[index][column]
value_type = type(value)
print(f'Value at index {index} and column {column}: {value} ({value_type})')
# Out:
# Value at index 2 and column city:  (<class 'str'>)

# %%
# Work around: Drop rows where the value in column 'city' is an empty string
mask = top_cities['city'] != ''
top_cities = top_cities[mask]
top_cities
# Out:
#               city                          company   latitude   longitude
# 0    San Francisco                             Digg  37.764726 -122.394523
# 8    San Francisco          The Climate Corporation  37.782809 -122.394354
# 10        New York                      Gilt Groupe  40.747270  -73.980064
# 17          London                           cScape  51.523676   -0.107843
# 19          London                          ProofHQ  51.532048   -0.011154
# 20   San Francisco                        99designs  37.795531 -122.400598
# 30          London                         Sososher  51.500152   -0.126236
# 39        New York                     PixelCrayons  28.682042   77.087502
# 44   San Francisco                        Cutcaster  37.798510 -122.457454
# 46        New York                 New York Designs  40.743264  -73.923427
# 133  San Francisco                    Carbonetworks  37.805289 -122.404448
# 134  San Francisco                           Minted  37.797435 -122.403175
# 138       New York                        StyleCard  40.738137  -74.005800
# 153         London                          The Tin  51.521290   -0.109780
# 157         London                         Squiz UK  51.521603   -0.083444
# 170  San Francisco                          Ecolect  37.776769 -122.410111
# 190  San Francisco                          Milobox  37.792979 -122.421242
# 202  San Francisco                          Ecolect  37.776769 -122.410111
# 222  San Francisco                          Milobox  37.792979 -122.421242
# 267         London                           Box UK  51.510774   -0.139245
# 276       New York            Fabian Rossano Studio  40.740371  -74.004777
# 332         London         Which Web Design Company  51.500152   -0.126236
# 354       New York                         Novalsys  40.728370  -73.992392
# 405         London                     Make It Rain  51.462600   -0.139082
# 412       New York                        Eastmedia  40.752409  -73.988676
# 429       New York            Rhxo Technology Group  40.762897  -73.974714
# 475       New York                        MindSmack  40.758492  -73.989987
# 498       New York  Hirshorn Zuckerman Design Group  40.756054  -73.986951
# 504         London                      Masterpiece  51.521913   -0.083375
# 530         London                           Boring  51.518372   -0.074068
# 607  San Francisco                     Bamboudesign  37.775087 -122.415199
# 611         London           Red Engineering Design  51.523421   -0.139861
# 626       New York                      Recyclebank  40.731048  -74.007813
# 679  San Francisco          Five Prime Therapeutics  37.767629 -122.393799
# 697  San Francisco                           Sunrun  37.787131 -122.404107
# 700         London           Rapid Action Packaging  51.469843   -0.261130
# 720       New York            Stemline Therapeutics  40.777565  -73.945933
# 728  San Francisco                      ACT Biotech  37.787131 -122.404107
# 738       New York                       Covet Shop  40.728740  -73.989324
# 767       New York                       Synesis IT  40.748873  -73.987106
# 776       New York                     Ramp Up Tech  40.746514  -73.993035
# 829  San Francisco       Osprey Pharmaceuticals USA  37.775196 -122.419204
# 862  San Francisco             Siluria Technologies  37.448491 -122.180281
# 882       New York                   Palyon Medical  40.756054  -73.986951
# 937       New York                           CPower  40.756054  -73.986951

# %%
def count_cities(column):
    """
    Args:
        column: the column for which you want the value counts 
    Returns:
        The value counts of the column 
    """
    value_counts = column.value_counts()
    index = value_counts.index.astype(str)
    return value_counts

# %%
count_cities(top_cities['city'])
# Out:
# New York         17
# San Francisco    16
# London           12
# Name: city, dtype: int64

# %% [markdown]
# ### The selected cities are `San Francisco`, `New York` and `London` 🏆

# %%
df.to_csv("data/top_cities.csv", index=False)

# %% [markdown]
# #### Make citi maps:
# 1. Get Coordinates
# 2. Create Map
# 3. Map Companies in each city

# %%
def get_city_map(city, zoom=15):
    '''
    Args: 
    City: the city you want to use to create your map. The city needs to be in the below dict cities
    Zoom: how close you want the map to be, defatul being 10
    Returns: the map, centralized in the city with the zoom of choice
    '''
    cities = {
        'New York': (40.7128, -74.0060),
        'San Francisco': (37.7749, -122.4194),
        'London': (51.5074, -0.1278),
    }

    city_coordinates = {'type': 'Point', 'coordinates': cities[city]}
    return folium.Map(location=city_coordinates['coordinates'], zoom_start=zoom)

# %%
ny_map = get_city_map('New York')
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0932ce6e3847765b2dbeb0dddf57ff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0932ce6e3847765b2dbeb0dddf57ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0932ce6e3847765b2dbeb0dddf57ff7 = L.map(
#                 &quot;map_f0932ce6e3847765b2dbeb0dddf57ff7&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80c5417db3276643cda07ce5bca62b84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sf_map = get_city_map('San Francisco')
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b598726104c93a914274a1013612feba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b598726104c93a914274a1013612feba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b598726104c93a914274a1013612feba = L.map(
#                 &quot;map_b598726104c93a914274a1013612feba&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d8b2adb2f5cdfaa9630f40e23b3843b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ld_map = get_city_map('London')
ld_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63f77152cf51520de9e4e93a8e405210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63f77152cf51520de9e4e93a8e405210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63f77152cf51520de9e4e93a8e405210 = L.map(
#                 &quot;map_63f77152cf51520de9e4e93a8e405210&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ce15d5ec77940ca579eb44558f937d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def map_markers(df,city,map_):
    """
    Args:
        df (dataframe): the dataframe from where we get the coordinates of each company  
        city (string): the city where we will map the companies from the df
        map (folium.Map): the map where the data wil be placed.
    Returns:
        the map with all markers
    """
    for i, row in df[df.city == city].iterrows():
        company = {
            "location":[row["latitude"], row["longitude"]],
            "tooltip" : row["company"]
        }
        
        icon = Icon(color = "blue",
                    prefix = "fa",
                    icon = "building",
                    icon_color = "white"
        )
            
        Marker(**company,icon = icon ).add_to(map_)
    return(map_)

# %%
ny_markers = map_markers(top_cities,'New York', ny_map)
ny_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0932ce6e3847765b2dbeb0dddf57ff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0932ce6e3847765b2dbeb0dddf57ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0932ce6e3847765b2dbeb0dddf57ff7 = L.map(
#                 &quot;map_f0932ce6e3847765b2dbeb0dddf57ff7&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80c5417db3276643cda07ce5bca62b84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var marker_44e05f7552c9c87ada68f5ea60d18d7a = L.marker(
#                 [40.74727, -73.9800645],
#                 {}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var icon_74e09dfc7869868fe69ce3b9874073d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_44e05f7552c9c87ada68f5ea60d18d7a.setIcon(icon_74e09dfc7869868fe69ce3b9874073d6);
#
#
#             marker_44e05f7552c9c87ada68f5ea60d18d7a.bindTooltip(
#                 `&lt;div&gt;
#                      Gilt Groupe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de63212be0f2406cf96a8aa221d13eda = L.marker(
#                 [28.682042, 77.087502],
#                 {}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var icon_a4ddc40bda3fe4e8847355c5d407935c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_de63212be0f2406cf96a8aa221d13eda.setIcon(icon_a4ddc40bda3fe4e8847355c5d407935c);
#
#
#             marker_de63212be0f2406cf96a8aa221d13eda.bindTooltip(
#                 `&lt;div&gt;
#                      PixelCrayons
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_87afa589b4bcd3fe14a235091001fab7 = L.marker(
#                 [40.743264, -73.923427],
#                 {}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var icon_4eda93c62f873b332972eff46fd6f93b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_87afa589b4bcd3fe14a235091001fab7.setIcon(icon_4eda93c62f873b332972eff46fd6f93b);
#
#
#             marker_87afa589b4bcd3fe14a235091001fab7.bindTooltip(
#                 `&lt;div&gt;
#                      New York Designs
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9fb5752bca467a8bd52c9f888e585e5c = L.marker(
#                 [40.738137, -74.0058],
#                 {}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var icon_bef1eacfb37990f0dfe505e2cbb8718d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9fb5752bca467a8bd52c9f888e585e5c.setIcon(icon_bef1eacfb37990f0dfe505e2cbb8718d);
#
#
#             marker_9fb5752bca467a8bd52c9f888e585e5c.bindTooltip(
#                 `&lt;div&gt;
#                      StyleCard
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f69952f9664add7c3cb6685d282bbc21 = L.marker(
#                 [40.740371, -74.004777],
#                 {}
#             ).addTo(map_f0932ce6e3847765b2dbeb0dddf57ff7);
#
#
#             var icon_1c989247847646e1821e7f7a72772e6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f69952f9664add7c3cb6685d282bbc21.setIcon(icon_1c989247847646e1821e7f

# %%
ld_markers = map_markers(top_cities,'London', ld_map)
ld_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63f77152cf51520de9e4e93a8e405210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63f77152cf51520de9e4e93a8e405210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63f77152cf51520de9e4e93a8e405210 = L.map(
#                 &quot;map_63f77152cf51520de9e4e93a8e405210&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ce15d5ec77940ca579eb44558f937d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var marker_da7199efa41ebb49d20f998a27e63ed4 = L.marker(
#                 [51.523676, -0.107843],
#                 {}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var icon_c73765269ba3002c239df8c4be5ddd99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_da7199efa41ebb49d20f998a27e63ed4.setIcon(icon_c73765269ba3002c239df8c4be5ddd99);
#
#
#             marker_da7199efa41ebb49d20f998a27e63ed4.bindTooltip(
#                 `&lt;div&gt;
#                      cScape
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_71e0592a2be2bc7d26397c3ec50ef735 = L.marker(
#                 [51.5320478, -0.011154],
#                 {}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var icon_49117f34398368dd66e03e33f41f4a66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_71e0592a2be2bc7d26397c3ec50ef735.setIcon(icon_49117f34398368dd66e03e33f41f4a66);
#
#
#             marker_71e0592a2be2bc7d26397c3ec50ef735.bindTooltip(
#                 `&lt;div&gt;
#                      ProofHQ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_225c6b0a61e568c2012c0d9b1cb4d5c6 = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var icon_2439a756044af4f43144e41449953065 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_225c6b0a61e568c2012c0d9b1cb4d5c6.setIcon(icon_2439a756044af4f43144e41449953065);
#
#
#             marker_225c6b0a61e568c2012c0d9b1cb4d5c6.bindTooltip(
#                 `&lt;div&gt;
#                      Sososher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cc40187a3062c4c2f30c5d44f1321530 = L.marker(
#                 [51.52129, -0.10978],
#                 {}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var icon_5c2a249be267351b99c93024167d0b82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cc40187a3062c4c2f30c5d44f1321530.setIcon(icon_5c2a249be267351b99c93024167d0b82);
#
#
#             marker_cc40187a3062c4c2f30c5d44f1321530.bindTooltip(
#                 `&lt;div&gt;
#                      The Tin
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1ad052b1c8a45b904547c49ddbd28f33 = L.marker(
#                 [51.521603, -0.083444],
#                 {}
#             ).addTo(map_63f77152cf51520de9e4e93a8e405210);
#
#
#             var icon_1b0e429b258acbd8eb9a0a01718bf107 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1ad052b1c8a45b904547c49ddbd28f33.setIcon(icon_1b0e429b258acbd8eb9a0a01718bf107);

# %%
sf_markers = map_markers(top_cities,'San Francisco', sf_map)
sf_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b598726104c93a914274a1013612feba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b598726104c93a914274a1013612feba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b598726104c93a914274a1013612feba = L.map(
#                 &quot;map_b598726104c93a914274a1013612feba&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d8b2adb2f5cdfaa9630f40e23b3843b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var marker_074b60bdc44f5711e7374319d4d1697c = L.marker(
#                 [51.523676, -0.107843],
#                 {}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var icon_021ebddd6bb476fd7e2aaaac7fa1c786 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_074b60bdc44f5711e7374319d4d1697c.setIcon(icon_021ebddd6bb476fd7e2aaaac7fa1c786);
#
#
#             marker_074b60bdc44f5711e7374319d4d1697c.bindTooltip(
#                 `&lt;div&gt;
#                      cScape
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8e79eb935bd9cb31276c5cc4677baa0c = L.marker(
#                 [51.5320478, -0.011154],
#                 {}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var icon_f1a305159b9904ba3291a7ce0a2e0fb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8e79eb935bd9cb31276c5cc4677baa0c.setIcon(icon_f1a305159b9904ba3291a7ce0a2e0fb6);
#
#
#             marker_8e79eb935bd9cb31276c5cc4677baa0c.bindTooltip(
#                 `&lt;div&gt;
#                      ProofHQ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_caff37cfe5ee3b8b4d146d386ffe2244 = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var icon_6513994f1f322d9783526083406797fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_caff37cfe5ee3b8b4d146d386ffe2244.setIcon(icon_6513994f1f322d9783526083406797fa);
#
#
#             marker_caff37cfe5ee3b8b4d146d386ffe2244.bindTooltip(
#                 `&lt;div&gt;
#                      Sososher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a947d1788f0ef278d030f622fbca08f8 = L.marker(
#                 [51.52129, -0.10978],
#                 {}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var icon_d00b4ad5c87c540015eba61df8d08dfa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a947d1788f0ef278d030f622fbca08f8.setIcon(icon_d00b4ad5c87c540015eba61df8d08dfa);
#
#
#             marker_a947d1788f0ef278d030f622fbca08f8.bindTooltip(
#                 `&lt;div&gt;
#                      The Tin
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61ee2f7518771f31f84c4f46140db31c = L.marker(
#                 [51.521603, -0.083444],
#                 {}
#             ).addTo(map_b598726104c93a914274a1013612feba);
#
#
#             var icon_7d3dcd0140b64154a8c3829781eff7f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_61ee2f7518771f31f84c4f46140db31c.setIcon(icon_7d3dcd0140b64154a8c3829781eff7f7);
